# %% [markdown]
# 1.上傳JSON檔案
#
# 點選左方"檔案"，即可以拖拉的方式上傳

# %% [markdown]
# 2.讀取JSON檔內容

# %%
import json

with open("路邊停車資訊.json",encoding="utf8") as file:
    data=json.load(file)
    for item in data["roadsides"]:
        print([item["rd_name"],item["rd_count"],item["use_cnt"]])
